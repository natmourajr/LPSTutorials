# %%
# %time
import os
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn import datasets
from sklearn import cross_validation
from sklearn import preprocessing

m_font_size = 20
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.05 µs

# %%
# %time
# Create Data
n_events = 50

# dados em 45^o
angle = np.pi/2
rotation_matrix = [[np.cos(angle), -np.sin(angle)],[np.sin(angle), np.cos(angle)]]

m_means = [-1.5,1.5]
m_vars = [0.5,0.5]

data_c1 = m_vars*np.random.randn(n_events,2)+m_means
data_c1 = np.inner(data_c1,rotation_matrix)

m_means = [1.5,-1.5]
m_vars = [0.5,0.5]

data_c2 = m_vars*np.random.randn(n_events,2)+m_means
data_c2 = np.inner(data_c2,rotation_matrix)

data = np.append(data_c1, data_c2,axis=0)
trgt = np.append(np.zeros(data_c1.shape[0]),np.ones(data_c2.shape[0]),axis=0)

# plot data
# %matplotlib inline  

fig = plt.figure(figsize=(10,10))

plt.plot(data[trgt==0,0],data[trgt==0,1],'bo',label='Class 1')
plt.plot(data[trgt==1,0],data[trgt==1,1],'ro',label='Class 2')

plt.legend(fontsize=m_font_size)
plt.grid()
plt.title('Synthetic DataBase',fontweight='bold',fontsize=m_font_size)
plt.xlabel('First Dimension',fontweight='bold',fontsize=m_font_size)
plt.ylabel('Second Dimension',fontweight='bold',fontsize=m_font_size)
#limits = [-5, 5]
#plt.xlim(limits)
#plt.ylim(limits)
# Out:
# CPU times: user 1 µs, sys: 1 µs, total: 2 µs
# Wall time: 3.81 µs

# %%
from ARTNet import TrnParams, ARTNet

art_obj = ARTNet()
art_obj.fit(data)
art_obj.clusters
# Out:
# Class ARTNet TrnParams
# Learning Rate: 0.10000
# Verbose: False
# [-1.51058198 -0.61737502]
# [ 1.55869053  1.64224219]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-47ff4d51c034> in <module>()
#       2
#       3 art_obj = ARTNet()
# ----> 4 art_obj.fit(data)
#       5 art_obj.clusters
#
# /home/natmourajr/Workspace/Projects/LPSTutorials/Functions/ARTNet.py in fit(self, data, trn_params)
#      86                                         dist = self.calc_dist(trn_data[ievent,:],self.clusters)
#      87                                         if dist > self.similarity_radius:
# ---> 88                                                 self.create_cluster(trn_data[ievent,:])
#      89                                         else:
#      90                                                 self.update_cluster(0,trn_data[ievent,:])
#
# /home/natmourajr/Workspace/Projects/LPSTutorials/Functions/ARTNet.py in create_cluster(self, new_cluster)
#      50                         self.clusters = new_cluster
#      51                 else:
# ---> 52                         self.clusters = np.append(self.clusters,new_cluster,axis=1)
#      53
#      54         def update_cluster(self, cluster_id, event):
#
# /home/natmourajr/.virtualenvs/lpsannecy/lib/python2.7/site-packages/numpy/lib/function_base.pyc in append(arr, values, axis)
#    4584         values = ravel(values)
#    4585         axis = arr.ndim-1
# -> 4586     return concatenate((arr, values), axis=axis)
#    4587
#
# IndexError: axis 1 out of bounds [0, 1)

# %%
a = np.append(art_obj.clusters,data[0,:])
print a
# Out:
# [ 1.55869053  1.64224219 -1.62083268 -1.8208942 ]
